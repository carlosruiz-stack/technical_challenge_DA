# %%
import pandas as pd
import numpy as py

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder

# %%
dataset_1A = pd.read_csv('dataset_1A.csv')
dataset_1A
# Out:
#      distance  consume  speed  temp_inside  temp_outside  AC  rain  sun  \
# 0        28.0      5.0     26         21.5            12   0     0    0
# 1        12.0      4.2     30         21.5            13   0     0    0
# 2        11.2      5.5     38         21.5            15   0     0    0
# 3        12.9      3.9     36         21.5            14   0     0    0
# 4        18.5      4.5     46         21.5            15   0     0    0
# ..        ...      ...    ...          ...           ...  ..   ...  ...
# 383      16.0      3.7     39         24.5            18   0     0    0
# 384      16.1      4.3     38         25.0            31   1     0    0
# 385      16.0      3.8     45         25.0            19   0     0    0
# 386      15.4      4.6     42         25.0            31   1     0    0
# 387      14.7      5.0     25         25.0            30   1     0    0
#
#      refill liters specials gas_type refill gas
# 0             45.0     rain      E10        E10
# 1             38.0     rain      E10       SP98
# 2             38.0     rain      E10       SP98
# 3             38.0     rain      E10       SP98
# 4             38.0     rain      E10       SP98
# ..             ...      ...      ...        ...
# 383           38.0     rain     SP98       SP98
# 384           38.0       AC     SP98       SP98
# 385           38.0     rain     SP98       SP98
# 386           38.0       AC     SP98       SP98
# 387           38.0       AC     SP98       SP98
#
# [388 rows x 12 columns]

# %%
dataset_1A['total_consumption'] = (dataset_1A['distance'] * dataset_1A['consume']) / 100
dataset_1A.head()
# Out:
#    distance  consume  speed  temp_inside  temp_outside  AC  rain  sun  \
# 0      28.0      5.0     26         21.5            12   0     0    0
# 1      12.0      4.2     30         21.5            13   0     0    0
# 2      11.2      5.5     38         21.5            15   0     0    0
# 3      12.9      3.9     36         21.5            14   0     0    0
# 4      18.5      4.5     46         21.5            15   0     0    0
#
#    refill liters specials gas_type refill gas  total_consumption
# 0           45.0     rain      E10        E10             1.4000
# 1           38.0     rain      E10       SP98             0.5040
# 2           38.0     rain      E10       SP98             0.6160
# 3           38.0     rain      E10       SP98             0.5031
# 4           38.0     rain      E10       SP98             0.8325

# %%
X = dataset_1A.drop(columns=['total_consumption'])
y = dataset_1A['total_consumption']

data = pd.get_dummies(dataset_1A, columns=['gas_type'], drop_first=True)

encoder = OneHotEncoder(drop='first', sparse=False)
gas_type_encoded = encoder.fit_transform(data[['gas_type']])
gas_type_encoded_df = pd.DataFrame(gas_type_encoded, columns=encoder.get_feature_names(['gas_type']))

X_encoded = pd.concat([X, gas_type_encoded_df], axis=1)

model = LinearRegression()
model.fit(X_encoded, y)

st.title("Total Consumption Prediction")

st.sidebar.header("Predictor Variables")
distance = st.sidebar.number_input("Distance", value=1.0)
consume = st.sidebar.number_input("Consume", value=7.0)
speed = st.sidebar.number_input("Speed", value=40)
temp_inside = st.sidebar.number_input("Temperature Inside", value=20.0)
temp_outside = st.sidebar.number_input("Temperature Outside", value=10.0)
ac = st.sidebar.checkbox("AC")
rain = st.sidebar.checkbox("Rain")
sun = st.sidebar.checkbox("Sun")
refill_liters = st.sidebar.number_input("Refill Liters", value=0.0)
refill_gas = st.sidebar.number_input("Refill Gas", value=0.0)
gas_type = st.sidebar.checkbox("Gas Type")

ac = int(ac)
rain = int(rain)
sun = int(sun)
gas_type = int(gas_type)

input_data = [
    [
        distance, consume, speed, temp_inside, temp_outside,
        ac, rain, sun, refill_liters, refill_gas, gas_type
    ] + gas_type_encoded_df.iloc[0].tolist()
]

predicted_consumption = model.predict(input_data)

st.write("Predicted Total Consumption:", predicted_consumption[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 7
#       4 data = pd.get_dummies(dataset_1A, columns=['gas_type'], drop_first=True)
#       6 encoder = OneHotEncoder(drop='first', sparse=False)
# ----> 7 gas_type_encoded = encoder.fit_transform(data[['gas_type']])
#       8 gas_type_encoded_df = pd.DataFrame(gas_type_encoded, columns=encoder.get_feature_names(['gas_type']))
#      10 X_encoded = pd.concat([X, gas_type_encoded_df], axis=1)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5796, in Index._get_indexer_strict(self, key, axis_name)
#    5793 else:
#    5794     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5796 self._raise_if_missing(keyarr, indexer, axis_name)
#    5798 keyarr = self.take(indexer)
#    5799 if isinstance(key, Index):
#    5800     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5856, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5854     if use_interval_msg:
#    5855         key = list(key)
# -> 5856     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5858 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5859 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['gas_type'], dtype='object')] are in the [columns]"
